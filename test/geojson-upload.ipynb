# %% [markdown]
# ### Notebook demonstrating how a geojson file can be uploaded to the TAP API endpoint as part of an HTTP request

# %%
import base64
import requests

#endpoint = "https://dw-tap.nrel.gov"

# For testing an endpoint running locally (for development purposes), use:
endpoint = "http://localhost:8080"

base_path = "/v1/timeseries/windspeed"

geojson_path = "obstacles-example.geojson"

# with open(geojson_path, "r") as f:
#     geojson = f.read()

# Decoding the contents of the geojson file into Base64
# geojson_bytes = geojson.encode('ascii')
# base64_bytes = base64.b64encode(geojson_bytes)
# base64_geojson = base64_bytes.decode('ascii')

# Example of decoding from Base64 
# base64_bytes = base64_geojson.encode('ascii')
# message_bytes = base64.b64decode(base64_bytes)
# message = message_bytes.decode('ascii')
# print(message)

params = {"height": "50.0m", 
          "lat": 40.712,
          "lon": -74.0059,
          "start_date": "20100302",
          "stop_date": "20100305",
          "vertical_interpolation": "linear",
          "spatial_interpolation": "idw"}

# Form complete url, with parameters
url = endpoint + base_path + "?"
for k, v in params.items():
    url += "%s=%s&" % (k, str(v))
url = url.rstrip('&')
print("Using the following URL:", url)

files = {'obstacles': open(geojson_path,'rb')}
r = requests.post(url, files=files)

print (r.text)

# Expected output: json string with non-empty "timestamps" and "windspeed" arrays.
# Out:
# Using the following URL: http://localhost:8080/v1/timeseries/windspeed?height=50.0m&lat=40.712&lon=-74.0059&start_date=20100302&stop_date=20100305&vertical_interpolation=linear&spatial_interpolation=idw
# {"timestamp":{"0":"2010-03-02 00:00:00","1":"2010-03-02 01:00:00","2":"2010-03-02 02:00:00","3":"2010-03-02 03:00:00","4":"2010-03-02 04:00:00","5":"2010-03-02 05:00:00","6":"2010-03-02 06:00:00","7":"2010-03-02 07:00:00","8":"2010-03-02 08:00:00","9":"2010-03-02 09:00:00","10":"2010-03-02 10:00:00","11":"2010-03-02 11:00:00","12":"2010-03-02 12:00:00","13":"2010-03-02 13:00:00","14":"2010-03-02 14:00:00","15":"2010-03-02 15:00:00","16":"2010-03-02 16:00:00","17":"2010-03-02 17:00:00","18":"2010-03-02 18:00:00","19":"2010-03-02 19:00:00","20":"2010-03-02 20:00:00","21":"2010-03-02 21:00:00","22":"2010-03-02 22:00:00","23":"2010-03-02 23:00:00","24":"2010-03-03 00:00:00","25":"2010-03-03 01:00:00","26":"2010-03-03 02:00:00","27":"2010-03-03 03:00:00","28":"2010-03-03 04:00:00","29":"2010-03-03 05:00:00","30":"2010-03-03 06:00:00","31":"2010-03-03 07:00:00","32":"2010-03-03 08:00:00","33":"2010-03-03 09:00:00","34":"2010-03-03 10:00:00","35":"2010-03-03 11:00:00","36":"2010-03-03 12:00: